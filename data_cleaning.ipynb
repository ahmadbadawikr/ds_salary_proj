# %%
import pandas as pd
df = pd.read_csv('glassdoor_jobs.csv')
df.head()
# Out:
#                            Job Title                   Salary Estimate  \
# 0             (Sr.) Data Scientist -  $17-$23 Per Hour(Glassdoor est.)
# 1                     Data Scientist  $17-$23 Per Hour(Glassdoor est.)
# 2       Medical Laboratory Scientist  $17-$23 Per Hour(Glassdoor est.)
# 3           Bioinformatics Scientist  $17-$23 Per Hour(Glassdoor est.)
# 4  Genomic Curator Quality Scientist  $17-$23 Per Hour(Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Thursday, June 11, 2020\n\nMerrick Bank is a t...     3.5
# 1  About Us\n\nMindoula is a next-generation beha...     3.8
# 2  Job Summary:\n\nPerforms and interprets tests ...     3.8
# 3  GENEWIZ is looking to welcome a Bioinformatics...     2.8
# 4  Job Title: * Genomic Curator Quality Scientist...    -1.0
#
#                Company Name              Location  Headquarters  \
# 0         Merrick Bank\n3.5                  Utah            -1
# 1  Mindoula Health Inc\n3.8              Maryland            -1
# 2     Cleveland Clinic\n3.8             Akron, OH            -1
# 3        GENEWIZ, Inc.\n2.8  South Plainfield, NJ            -1
# 4          Golden Helix Inc           Bozeman, MT            -1
#
#                     Size  Founded       Type of ownership  \
# 0   201 to 500 Employees     1997       Company - Private
# 1    51 to 200 Employees     2013       Company - Private
# 2       10000+ Employees     1921  Nonprofit Organization
# 3  501 to 1000 Employees     1999        Company - Public
# 4                     -1       -1                      -1
#
#                            Industry                     Sector  \
# 0             Banks & Credit Unions                    Finance
# 1  Health Care Services & Hospitals                Health Care
# 2  Health Care Services & Hospitals                Health Care
# 3         Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 4                                -1                         -1
#
#                       Revenue  Competitors
# 0    Unknown / Non-Applicable           -1
# 1    Unknown / Non-Applicable           -1
# 2      $2 to $5 billion (USD)           -1
# 3  $100 to $500 million (USD)           -1
# 4                          -1           -1

# %%
#salary parsing

df['hourly'] = df['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
df['employer_provided'] = df['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)

df = df[df['Salary Estimate'] != "-1"]
salary = df['Salary Estimate'].apply(lambda x: x.split('(')[0])
minus_Kd = salary.apply(lambda x: x.replace('K','').replace('$',''))

min_hr = minus_Kd.apply(lambda x: x.lower().replace('per hour','').replace('employer provided salary:',''))

df['min_salary'] = min_hr.apply(lambda x: int(x.split('-')[0]))
df['max_salary'] = min_hr.apply(lambda x: int(x.split('-')[1]))
df['avg_salary'] = (df.min_salary + df.max_salary)/2

#Company name text only
df['company_txt'] = df.apply(lambda x: x['Company Name'] if x['Rating'] <0 else x['Company Name'][:-3], axis=1)

#State field
df['job_state'] = df['Location'].apply(lambda x: x.split(',')[0])
df.job_state.value_counts()

df['same_state'] = df.apply(lambda x: 1 if x.Location == x.Headquarters else 0,axis=1)
#Company age
df['age'] = df.Founded.apply(lambda x: x if x<1 else 2020-x)

#job desc parsing
df['python_yn'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
df['R_yn'] = df['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() or 'r-studio' in x.lower() else 0)
df.R_yn.value_counts()
df['spark'] = df['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)
df.spark.value_counts()
df['aws'] = df['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)
df.aws.value_counts()
df['excel'] = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
df.excel.value_counts()

df.columns

df.to_csv('Salary_data_cleaned.csv', index=False)
pd.read_csv('Salary_data_cleaned.csv')
# Out:
#                                             Job Title  \
# 0                              (Sr.) Data Scientist -
# 1                                      Data Scientist
# 2                        Medical Laboratory Scientist
# 3                            Bioinformatics Scientist
# 4                   Genomic Curator Quality Scientist
# ..                                                ...
# 65                                     Data Scientist
# 66                                     DATA SCIENTIST
# 67  Preclinical research scientist - Autoimmunity ...
# 68       Senior Research Statistician- Data Scientist
# 69          Data Scientist, Cloud Business Operations
#
#                      Salary Estimate  \
# 0   $17-$23 Per Hour(Glassdoor est.)
# 1   $17-$23 Per Hour(Glassdoor est.)
# 2   $17-$23 Per Hour(Glassdoor est.)
# 3   $17-$23 Per Hour(Glassdoor est.)
# 4   $17-$23 Per Hour(Glassdoor est.)
# ..                               ...
# 65      $120K-$193K (Glassdoor est.)
# 66      $120K-$193K (Glassdoor est.)
# 67      $120K-$193K (Glassdoor est.)
# 68      $120K-$193K (Glassdoor est.)
# 69      $120K-$193K (Glassdoor est.)
#
#                                       Job Description  Rating  \
# 0   Thursday, June 11, 2020\n\nMerrick Bank is a t...     3.5
# 1   About Us\n\nMindoula is a next-generation beha...     3.8
# 2   Job Summary:\n\nPerforms and interprets tests ...     3.8
# 3   GENEWIZ is looking to welcome a Bioinformatics...     2.8
# 4   Job Title: * Genomic Curator Quality Scientist...    -1.0
# ..                                                ...     ...
# 65  Description\n\nJob Description:\n\nThis role u...     3.6
# 66  JOB SUMMARY\n\nThe position will focus on buil...     3.8
# 67  The preclinical research scientist (RS) – Auto...    -1.0
# 68  Acuity is seeking a Senior Research Statistici...     4.9
# 69  53303\n\nAbout NetApp\n\nNetApp provides softw...     3.8
#
#                 Company Name              Location  Headquarters  \
# 0          Merrick Bank\n3.5                  Utah            -1
# 1   Mindoula Health Inc\n3.8              Maryland            -1
# 2      Cleveland Clinic\n3.8             Akron, OH            -1
# 3         GENEWIZ, Inc.\n2.8  South Plainfield, NJ            -1
# 4           Golden Helix Inc           Bozeman, MT            -1
# ..                       ...                   ...           ...
# 65               Leidos\n3.6            Reston, VA            -1
# 66    Blessing Hospital\n3.8            Quincy, IL            -1
# 67    Landos Biopharma, Inc.        Blacksburg, VA            -1
# 68     Acuity Insurance\n4.9         Sheboygan, WI            -1
# 69               NetApp\n3.8         Sunnyvale, CA            -1
#
#                       Size  Founded       Type of ownership  ... avg_salary  \
# 0     201 to 500 Employees     1997       Company - Private  ...       20.0
# 1      51 to 200 Employees     2013       Company - Private  ...       20.0
# 2         10000+ Employees     1921  Nonprofit Organization  ...       20.0
# 3    501 to 1000 Employees     1999        Company - Public  ...       20.0
# 4                       -1       -1                      -1  ...       20.0
# ..                     ...      ...                     ...  ...        ...
# 65        10000+ Employees     1969        Company - Public  ...      156.5
# 66  1001 to 5000 Employees     1875  Nonprofit Organization  ...      156.5
# 67       1 to 50 Employees       -1        Company - Public  ...      156.5
# 68  1001 to 5000 Employees     1925       Company - Private  ...      156.5
# 69        10000+ Employees     1992        Company - Public  ...      156.5
#
#                company_txt         job_state  same_state  age  python_yn  \
# 0           Merrick Bank\n              Utah           0   23          1
# 1    Mindoula Health Inc\n          Maryland           0    7          1
# 2       Cleveland Clinic\n             Akron           0   99          0
# 3          GENEWIZ, Inc.\n  South Plainfield           0   21          0
# 4         Golden Helix Inc           Bozeman           0   -1          1
# ..                     ...               ...         ...  ...        ...
# 65                Leidos\n            Reston           0   51          1
# 66     Blessing Hospital\n            Quincy           0  145          1
# 67  Landos Biopharma, Inc.        Blacksburg           0   -1          0
# 68      Acuity Insurance\n         Sheboygan           0   95          0
# 69                NetApp\n         Sunnyvale           0   28          0
#
#     R_yn  spark  aws excel
# 0      0      0    1     1
# 1      0      1    0     0
# 2      0      0    0     0
# 3      0      0    0     1
# 4      0      0    0     0
# ..   ...    ...  ...   ...
# 65     0      1    1     0
# 66     0      0    1     1
# 67     0      0    0     1
# 68     0      0    0     0
# 69     0      0    1     1
#
# [70 rows x 28 columns]
